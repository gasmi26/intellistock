# %%
# %pip install "numpy<2"
# Out:
# Requirement already satisfied: numpy<2 in c:\users\kiit\anaconda3\lib\site-packages (1.26.4)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~ensorflow (C:\Users\KIIT\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow (C:\Users\KIIT\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow (C:\Users\KIIT\anaconda3\Lib\site-packages)

# %%
# %pip install --upgrade pandas scikit-learn
# Out:
# Requirement already satisfied: pandas in c:\users\kiit\anaconda3\lib\site-packages (3.0.3)
# Requirement already satisfied: scikit-learn in c:\users\kiit\anaconda3\lib\site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\kiit\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kiit\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\kiit\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\kiit\anaconda3\lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\kiit\anaconda3\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\kiit\anaconda3\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in c:\users\kiit\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~ensorflow (C:\Users\KIIT\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow (C:\Users\KIIT\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow (C:\Users\KIIT\anaconda3\Lib\site-packages)

# %%
import numpy as np
print(np.__version__)
# Out:
# 1.26.4

# %%
import pandas as pd
import numpy as np

np.random.seed(42)
dates = pd.date_range(start="2022-01-01", end="2024-12-31", freq="W")
skus = ["ITEM_001", "ITEM_002", "ITEM_003"]

rows = []
for sku in skus:
    for date in dates:
        sales = np.random.poisson(lam=100) + np.random.randint(-10, 10)
        rows.append({"date": date, "sku": sku, "sales": max(0, sales)})

df = pd.DataFrame(rows)
df.to_csv("walmart_sales.csv", index=False)
print(df.head(10))
print(f"Total rows: {len(df)}")
# Out:
# C:\Users\KIIT\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:23: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.8.7' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\KIIT\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:56: UserWarning: Pandas requires version '1.4.2' or newer of 'bottleneck' (version '1.3.7' currently installed).
#   from pandas.core import (
#         date       sku  sales
# 0 2022-01-02  ITEM_001     96
# 1 2022-01-09  ITEM_001    117
# 2 2022-01-16  ITEM_001     78
# 3 2022-01-23  ITEM_001     79
# 4 2022-01-30  ITEM_001    104
# 5 2022-02-06  ITEM_001    102
# 6 2022-02-13  ITEM_001    100
# 7 2022-02-20  ITEM_001     95
# 8 2022-02-27  ITEM_001     82
# 9 2022-03-06  ITEM_001    119
# Total rows: 471

# %%
import sqlite3

# Create database connection
conn = sqlite3.connect("intellistock.db")

# Store dataset into SQLite
df.to_sql("sales", conn, if_exists="replace", index=False)

print("Database created successfully!")

# Verify data
test = pd.read_sql("SELECT * FROM sales LIMIT 5", conn)

print(test)

# Close connection
conn.close()
# Out:
# Database created successfully!
#                   date       sku  sales
# 0  2022-01-02 00:00:00  ITEM_001     96
# 1  2022-01-09 00:00:00  ITEM_001    117
# 2  2022-01-16 00:00:00  ITEM_001     78
# 3  2022-01-23 00:00:00  ITEM_001     79
# 4  2022-01-30 00:00:00  ITEM_001    104

# %%
# %pip install chronos-forecasting
# Out:
# Requirement already satisfied: chronos-forecasting in c:\users\kiit\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: accelerate<2,>=0.34 in c:\users\kiit\anaconda3\lib\site-packages (from chronos-forecasting) (1.13.0)
# Requirement already satisfied: einops<1,>=0.7.0 in c:\users\kiit\anaconda3\lib\site-packages (from chronos-forecasting) (0.8.2)
# Requirement already satisfied: numpy<3,>=1.21 in c:\users\kiit\anaconda3\lib\site-packages (from chronos-forecasting) (1.26.4)
# Requirement already satisfied: scikit-learn<2,>=1.6.0 in c:\users\kiit\anaconda3\lib\site-packages (from chronos-forecasting) (1.8.0)
# Requirement already satisfied: torch<3,>=2.2 in c:\users\kiit\anaconda3\lib\site-packages (from chronos-forecasting) (2.12.0)
# Requirement already satisfied: transformers<5,>=4.41 in c:\users\kiit\anaconda3\lib\site-packages (from chronos-forecasting) (4.57.6)
# Requirement already satisfied: packaging>=20.0 in c:\users\kiit\anaconda3\lib\site-packages (from accelerate<2,>=0.34->chronos-forecasting) (24.1)
# Requirement already satisfied: psutil in c:\users\kiit\anaconda3\lib\site-packages (from accelerate<2,>=0.34->chronos-forecasting) (5.9.0)
# Requirement already satisfied: pyyaml in c:\users\kiit\anaconda3\lib\site-packages (from accelerate<2,>=0.34->chronos-forecasting) (6.0.1)
# Requirement already satisfied: huggingface_hub>=0.21.0 in c:\users\kiit\anaconda3\lib\site-packages (from accelerate<2,>=0.34->chronos-forecasting) (0.36.2)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\kiit\anaconda3\lib\site-packages (from accelerate<2,>=0.34->chronos-forecasting) (0.7.0)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\kiit\anaconda3\lib\site-packages (from scikit-learn<2,>=1.6.0->chronos-forecasting) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\kiit\anaconda3\lib\site-packages (from scikit-learn<2,>=1.6.0->chronos-forecasting) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\kiit\anaconda3\lib\site-packages (from scikit-learn<2,>=1.6.0->chronos-forecasting) (3.6.0)
# Requirement already satisfied: filelock in c:\users\kiit\anaconda3\lib\site-packages (from torch<3,>=2.2->chronos-forecasting) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\kiit\anaconda3\lib\site-packages (from torch<3,>=2.2->chronos-forecasting) (4.15.0)
# Requirement already satisfied: setuptools<82 in c:\users\kiit\anaconda3\lib\site-packages (from torch<3,>=2.2->chronos-forecasting) (75.1.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\kiit\anaconda3\lib\site-packages (from torch<3,>=2.2->chronos-forecasting) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\kiit\anaconda3\lib\site-packages (from torch<3,>=2.2->chronos-forecasting) (3.3)
# Requirement already satisfied: jinja2 in c:\users\kiit\anaconda3\lib\site-packages (from torch<3,>=2.2->chronos-forecasting) (3.1.4)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\kiit\anaconda3\lib\site-packages (from torch<3,>=2.2->chronos-forecasting) (2024.6.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\kiit\anaconda3\lib\site-packages (from transformers<5,>=4.41->chronos-forecasting) (2024.9.11)
# Requirement already satisfied: requests in c:\users\kiit\anaconda3\lib\site-packages (from transformers<5,>=4.41->chronos-forecasting) (2.34.2)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\kiit\anaconda3\lib\site-packages (from transformers<5,>=4.41->chronos-forecasting) (0.22.2)
# Requirement already satisfied: tqdm>=4.27 in c:\users\kiit\anaconda3\lib\site-packages (from transformers<5,>=4.41->chronos-forecasting) (4.66.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\kiit\anaconda3\lib\site-packages (from sympy>=1.13.3->torch<3,>=2.2->chronos-forecasting) (1.3.0)
# Requirement already satisfied: colorama in c:\users\kiit\anaconda3\lib\site-packages (from tqdm>=4.27->transformers<5,>=4.41->chronos-forecasting) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\kiit\anaconda3\lib\site-packages (from jinja2->torch<3,>=2.2->chronos-forecasting) (2.1.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\kiit\anaconda3\lib\site-packages (from requests->transformers<5,>=4.41->chronos-forecasting) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kiit\anaconda3\lib\site-packages (from requests->transformers<5,>=4.41->chronos-forecasting) (3.7)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\kiit\anaconda3\lib\site-packages (from requests->transformers<5,>=4.41->chronos-forecasting) (2.2.3)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\kiit\anaconda3\lib\site-packages (from requests->transformers<5,>=4.41->chronos-forecasting) (2024.12.14)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~ensorflow (C:\Users\KIIT\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow (C:\Users\KIIT\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow (C:\Users\KIIT\anaconda3\Lib\site-packages)

# %%
import torch
import pandas as pd
import sqlite3

def get_context(sku, n=52):

    # Connect to SQLite database
    conn = sqlite3.connect("intellistock.db")

    # Read data for selected SKU
    df = pd.read_sql(
        f"SELECT * FROM sales WHERE sku='{sku}'",
        conn
    )

    # Close connection
    conn.close()

    # Take last n sales values
    series = df.tail(n)["sales"].tolist()

    # Convert to tensor
    context = torch.tensor(series, dtype=torch.float32)

    return context

print("Context function ready!")

print(f"Sample context shape: {get_context('ITEM_001').shape}")
# Out:
# Context function ready!
# Sample context shape: torch.Size([52])

# %%
import chronos
print("Chronos ready!")
# Out:
# Chronos ready!

# %%
# %pip install huggingface_hub[hf_xet]
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: huggingface_hub[hf_xet] in c:\users\kiit\anaconda3\lib\site-packages (0.36.2)
# Requirement already satisfied: filelock in c:\users\kiit\anaconda3\lib\site-packages (from huggingface_hub[hf_xet]) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\kiit\anaconda3\lib\site-packages (from huggingface_hub[hf_xet]) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\kiit\anaconda3\lib\site-packages (from huggingface_hub[hf_xet]) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\kiit\anaconda3\lib\site-packages (from huggingface_hub[hf_xet]) (6.0.1)
# Requirement already satisfied: requests in c:\users\kiit\anaconda3\lib\site-packages (from huggingface_hub[hf_xet]) (2.34.2)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\kiit\anaconda3\lib\site-packages (from huggingface_hub[hf_xet]) (4.66.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\kiit\anaconda3\lib\site-packages (from huggingface_hub[hf_xet]) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in c:\users\kiit\anaconda3\lib\site-packages (from huggingface_hub[hf_xet]) (1.5.0)
# Requirement already satisfied: colorama in c:\users\kiit\anaconda3\lib\site-packages (from tqdm>=4.42.1->huggingface_hub[hf_xet]) (0.4.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\kiit\anaconda3\lib\site-packages (from requests->huggingface_hub[hf_xet]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kiit\anaconda3\lib\site-packages (from requests->huggingface_hub[hf_xet]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\kiit\anaconda3\lib\site-packages (from requests->huggingface_hub[hf_xet]) (2.2.3)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\kiit\anaconda3\lib\site-packages (from requests->huggingface_hub[hf_xet]) (2024.12.14)
# WARNING: Ignoring invalid distribution ~ensorflow (C:\Users\KIIT\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow (C:\Users\KIIT\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow (C:\Users\KIIT\anaconda3\Lib\site-packages)

# %%
import torch
from chronos import ChronosPipeline

pipe = ChronosPipeline.from_pretrained(
    "amazon/chronos-t5-small",
    device_map="cpu",
    torch_dtype=torch.float32
)

print("Chronos model loaded!")
# Out:
# `torch_dtype` is deprecated! Use `dtype` instead!
# Chronos model loaded!

# %%
import chronos
print(chronos.__version__)

# check what arguments predict() accepts
import inspect
print(inspect.signature(pipe.predict))
# Out:
# 2.2.2
# (inputs: Union[torch.Tensor, List[torch.Tensor]], prediction_length: Optional[int] = None, num_samples: Optional[int] = None, temperature: Optional[float] = None, top_k: Optional[int] = None, top_p: Optional[float] = None, limit_prediction_length: bool = False) -> torch.Tensor

# %%
import torch
import pandas as pd
import sqlite3

def get_context(sku, n=52):

    # Connect to SQLite database
    conn = sqlite3.connect("intellistock.db")

    # Read SKU data
    df = pd.read_sql(
        f"SELECT * FROM sales WHERE sku='{sku}'",
        conn
    )

    # Close connection
    conn.close()

    # Get last n sales values
    series = df.tail(n)["sales"].tolist()

    # Convert to tensor
    context = torch.tensor(series, dtype=torch.float32)

    return context


def predict_demand(sku, horizon=4):

    context = get_context(sku, n=52)

    forecast = pipe.predict(
        inputs=[context],
        prediction_length=horizon,
        num_samples=20
    )

    median_demand = float(
        forecast[0].median(dim=0).values.sum()
    )

    return round(median_demand, 2)


# Test all SKUs
for sku in ["ITEM_001", "ITEM_002", "ITEM_003"]:

    demand = predict_demand(sku)

    print(f"{sku} → predicted 4-week demand: {demand} units")
# Out:
# ITEM_001 → predicted 4-week demand: 405.83 units
# ITEM_002 → predicted 4-week demand: 405.24 units
# ITEM_003 → predicted 4-week demand: 404.87 units

# %%
# %pip install langchain-community faiss-cpu sentence-transformers
# Out:
# Requirement already satisfied: langchain-community in c:\users\kiit\anaconda3\lib\site-packages (0.4.2)
# Requirement already satisfied: faiss-cpu in c:\users\kiit\anaconda3\lib\site-packages (1.14.2)
# Requirement already satisfied: sentence-transformers in c:\users\kiit\anaconda3\lib\site-packages (5.5.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\kiit\anaconda3\lib\site-packages (from langchain-community) (3.10.5)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\kiit\anaconda3\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.7 in c:\users\kiit\anaconda3\lib\site-packages (from langchain-community) (1.0.7)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in c:\users\kiit\anaconda3\lib\site-packages (from langchain-community) (1.4.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in c:\users\kiit\anaconda3\lib\site-packages (from langchain-community) (0.8.5)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\kiit\anaconda3\lib\site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\kiit\anaconda3\lib\site-packages (from langchain-community) (2.14.1)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\kiit\anaconda3\lib\site-packages (from langchain-community) (6.0.1)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in c:\users\kiit\anaconda3\lib\site-packages (from langchain-community) (2.34.2)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in c:\users\kiit\anaconda3\lib\site-packages (from langchain-community) (1.4.46)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\kiit\anaconda3\lib\site-packages (from langchain-community) (8.2.3)
# Requirement already satisfied: packaging in c:\users\kiit\anaconda3\lib\site-packages (from faiss-cpu) (24.1)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in c:\users\kiit\anaconda3\lib\site-packages (from sentence-transformers) (4.57.6)
# Requirement already satisfied: huggingface-hub>=0.23.0 in c:\users\kiit\anaconda3\lib\site-packages (from sentence-transformers) (0.36.2)
# Requirement already satisfied: torch>=1.11.0 in c:\users\kiit\anaconda3\lib\site-packages (from sentence-transformers) (2.12.0)
# Requirement already satisfied: scikit-learn>=0.22.0 in c:\users\kiit\anaconda3\lib\site-packages (from sentence-transformers) (1.8.0)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\kiit\anaconda3\lib\site-packages (from sentence-transformers) (1.17.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\kiit\anaconda3\lib\site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: tqdm>=4.0.0 in c:\users\kiit\anaconda3\lib\site-packages (from sentence-transformers) (4.66.5)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\kiit\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\kiit\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\kiit\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\kiit\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\kiit\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\kiit\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.11.0)
# Requirement already satisfied: filelock in c:\users\kiit\anaconda3\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\kiit\anaconda3\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (2024.6.1)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in c:\users\kiit\anaconda3\lib\site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (1.1.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\kiit\anaconda3\lib\site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (2.8.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\kiit\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in c:\users\kiit\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (0.0.15)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\kiit\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (0.16.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\kiit\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.27.0)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\kiit\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\kiit\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\kiit\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.7.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\kiit\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\kiit\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (0.21.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\kiit\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\kiit\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kiit\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\kiit\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.2.3)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\kiit\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2024.12.14)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\kiit\anaconda3\lib\site-packages (from scikit-learn>=0.22.0->sentence-transformers) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\kiit\anaconda3\lib\site-packages (from scikit-learn>=0.22.0->sentence-transformers) (3.6.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\kiit\anaconda3\lib\site-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-community) (3.0.1)
# Requirement already satisfied: setuptools<82 in c:\users\kiit\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (75.1.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\kiit\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\kiit\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: jinja2 in c:\users\kiit\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: colorama in c:\users\kiit\anaconda3\lib\site-packages (from tqdm>=4.0.0->sentence-transformers) (0.4.6)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\kiit\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2024.9.11)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\kiit\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\kiit\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: anyio in c:\users\kiit\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\kiit\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\kiit\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\kiit\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\kiit\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain-community) (2.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\kiit\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain-community) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\kiit\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain-community) (2.20.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\kiit\anaconda3\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\kiit\anaconda3\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~ensorflow (C:\Users\KIIT\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow (C:\Users\KIIT\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow (C:\Users\KIIT\anaconda3\Lib\site-packages)

# %%
# %pip install faiss-gpu
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~ensorflow (C:\Users\KIIT\anaconda3\Lib\site-packages)
# ERROR: Could not find a version that satisfies the requirement faiss-gpu (from versions: none)
# ERROR: No matching distribution found for faiss-gpu

# %%
# %pip install tf-keras
# Out:
# Collecting tf-keras
#   Downloading tf_keras-2.21.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: tensorflow<2.22,>=2.21 in c:\users\kiit\anaconda3\lib\site-packages (from tf-keras) (2.21.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\kiit\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\kiit\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in c:\users\kiit\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\kiit\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (0.6.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\kiit\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\kiit\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\kiit\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (3.4.0)
# Requirement already satisfied: packaging in c:\users\kiit\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (24.1)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in c:\users\kiit\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (7.34.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\kiit\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (2.34.2)
# Requirement already satisfied: setuptools in c:\users\kiit\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\kiit\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\kiit\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (3.1.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\kiit\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\kiit\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\kiit\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (1.74.0)
# Requirement already satisfied: keras>=3.12.0 in c:\users\kiit\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (3.13.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\kiit\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (1.26.4)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in c:\users\kiit\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (3.11.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\kiit\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (0.5.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\kiit\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow<2.22,>=2.21->tf-keras) (0.44.0)
# Requirement already satisfied: rich in c:\users\kiit\anaconda3\lib\site-packages (from keras>=3.12.0->tensorflow<2.22,>=2.21->tf-keras) (13.7.1)
# Requirement already satisfied: namex in c:\users\kiit\anaconda3\lib\site-packages (from keras>=3.12.0->tensorflow<2.22,>=2.21->tf-keras) (0.1.0)
# Requirement already satisfied: optree in c:\users\kiit\anaconda3\lib\site-packages (from keras>=3.12.0->tensorflow<2.22,>=2.21->tf-keras) (0.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\kiit\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.22,>=2.21->tf-keras) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kiit\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.22,>=2.21->tf-keras) (3.7)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\kiit\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.22,>=2.21->tf-keras) (2.2.3)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\kiit\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.22,>=2.21->tf-keras) (2024.12.14)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\kiit\anaconda3\lib\site-packages (from rich->keras>=3.12.0->tensorflow<2.22,>=2.21->tf-keras) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\kiit\anaconda3\lib\site-packages (from rich->keras>=3.12.0->tensorflow<2.22,>=2.21->tf-keras) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\kiit\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow<2.22,>=2.21->tf-keras) (0.1.0)
# Downloading tf_keras-2.21.0-py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------------ --------------------------- 0.5/1.7 MB 8.5 MB/s eta 0:00:01
#    ------------ --------------------------- 0.5/1.7 MB 8.5 MB/s eta 0:00:01
#    ------------------ --------------------- 0.8/1.7 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------- -- 1.6/1.7 MB 2.0 MB/s eta 0:00:01
#    ------------------------------------- -- 1.6/1.7 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 1.4 MB/s eta 0:00:00
# Installing collected packages: tf-keras
# Successfully installed tf-keras-2.21.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~ensorflow (C:\Users\KIIT\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow (C:\Users\KIIT\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow (C:\Users\KIIT\anaconda3\Lib\site-packages)

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"
os.environ["HF_HUB_DISABLE_SYMLINKS_WARNING"] = "1"

# %%
from langchain_community.vectorstores import FAISS
from langchain_community.embeddings import HuggingFaceEmbeddings

# Supply chain knowledge base
docs = [
    "Copper prices forecast to rise 12% in Q3 due to Chile mine strike.",
    "Supplier A lead time increased from 3 to 6 weeks updated May 2025.",
    "Sea freight rates from Shanghai up 30% use air for urgent orders.",
    "Supplier B offers 8% volume discount above 500 units.",
    "Steel shortage expected in Q4 due to port strikes in South Korea.",
    "Supplier C has been blacklisted in winter months due to delays.",
    "Cotton prices stable no major disruptions expected this quarter.",
    "Warehouse storage costs rising 15% recommend reducing buffer stock.",
]

# Load embedding model
embedder = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

# Build FAISS index
vectorstore = FAISS.from_texts(docs, embedder)
retriever = vectorstore.as_retriever(search_kwargs={"k": 3})

print("FAISS vector store ready!")
print(f"Total documents indexed: {len(docs)}")
# Out:
# FAISS vector store ready!
# Total documents indexed: 8

# %%
# Test semantic search

query = "Which suppliers have delivery delays?"

results = retriever.invoke(query)

print("\nTop 3 Relevant Results:\n")

for i, doc in enumerate(results, 1):

    print(f"Result {i}:")
    print(doc.page_content)
    print()
# Out:
# Top 3 Relevant Results:
#
# Result 1:
# Supplier C has been blacklisted in winter months due to delays.
#
# Result 2:
# Supplier A lead time increased from 3 to 6 weeks updated May 2025.
#
# Result 3:
# Sea freight rates from Shanghai up 30% use air for urgent orders.

# %%
# Create reusable market research function

def market_research(query):

    results = retriever.invoke(query)

    print("\nTop Market Insights:\n")

    for i, doc in enumerate(results, 1):

        print(f"Result {i}:")
        print(doc.page_content)
        print()


# Test function
market_research("Which suppliers are risky?")
# Out:
# Top Market Insights:
#
# Result 1:
# Supplier B offers 8% volume discount above 500 units.
#
# Result 2:
# Supplier C has been blacklisted in winter months due to delays.
#
# Result 3:
# Sea freight rates from Shanghai up 30% use air for urgent orders.

# %%
# %pip install pulp
# Out:
# Requirement already satisfied: pulp in c:\users\kiit\anaconda3\lib\site-packages (3.1.1)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~ensorflow (C:\Users\KIIT\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow (C:\Users\KIIT\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow (C:\Users\KIIT\anaconda3\Lib\site-packages)

# %%
from pulp import *

# ==========================================
# Procurement Optimizer
# ==========================================

def optimize_inventory(
    predicted_demand,
    unit_cost=50,
    storage_cost=2,
    budget=30000,
    storage_capacity=1000,
    min_order=100
):

    # Create optimization problem
    model = LpProblem(
        "Inventory_Optimization",
        LpMinimize
    )

    # Decision variable
    order_qty = LpVariable(
        "order_quantity",
        lowBound=min_order,
        cat="Integer"
    )

    # Objective Function
    model += (
        unit_cost * order_qty
        +
        storage_cost * order_qty
    )

    # Constraints

    # Must satisfy demand
    model += order_qty >= predicted_demand

    # Budget constraint
    model += unit_cost * order_qty <= budget

    # Storage constraint
    model += order_qty <= storage_capacity

    # Solve
    model.solve()

    return {
        "status": LpStatus[model.status],
        "recommended_order": int(order_qty.varValue),
        "total_cost": round(value(model.objective), 2)
    }

# %%
# ==========================================
# Example Forecast
# ==========================================

predicted_demand = 420

result = optimize_inventory(
    predicted_demand=predicted_demand
)

print("\nOptimization Result:\n")

print(result)
# Out:
# Optimization Result:
#
# {'status': 'Optimal', 'recommended_order': 420, 'total_cost': 21840.0}

# %%
# ==========================================
# AI Critic / Refiner
# ==========================================

def critic_refiner(
    predicted_demand,
    optimization_result,
    market_query
):

    # Get market insights
    insights = retriever.invoke(market_query)

    issues = []

    # Extract text
    insight_text = " ".join([
        doc.page_content.lower()
        for doc in insights
    ])

    # ======================================
    # Rule 1 — Supplier Risk
    # ======================================

    if "blacklisted" in insight_text:
        issues.append(
            "Risk detected: Supplier issues found."
        )

    # ======================================
    # Rule 2 — Freight Risk
    # ======================================

    if "freight" in insight_text:
        issues.append(
            "Logistics warning: Freight costs rising."
        )

    # ======================================
    # Rule 3 — Over Ordering
    # ======================================

    if optimization_result["recommended_order"] > predicted_demand * 1.5:

        issues.append(
            "Overstock risk detected."
        )

    # ======================================
    # Final Decision
    # ======================================

    if len(issues) == 0:

        status = "PASS"

    else:

        status = "REVISE"

    return {
        "status": status,
        "issues": issues
    }

# %%
# ==========================================
# Test Critic / Refiner
# ==========================================

review = critic_refiner(
    predicted_demand=420,
    optimization_result=result,
    market_query="Which suppliers are risky?"
)

print("\nCritic Review:\n")

print(review)
# Out:
# Critic Review:
#
# {'status': 'REVISE', 'issues': ['Risk detected: Supplier issues found.', 'Logistics warning: Freight costs rising.']}

# %%
# ==========================================
# Executive Procurement Report Generator
# ==========================================

def generate_procurement_report(
    sku,
    predicted_demand,
    optimization_result,
    critic_result,
    market_query
):

    # Get market insights
    insights = retriever.invoke(market_query)

    # Extract insight text
    market_insights = [
        doc.page_content
        for doc in insights
    ]

    # ======================================
    # Generate Executive Summary
    # ======================================

    print("\n======================================")
    print(" PROCUREMENT EXECUTIVE REPORT ")
    print("======================================\n")

    print(f"SKU: {sku}")

    print(
        f"\nPredicted 4-Week Demand: "
        f"{predicted_demand} units"
    )

    print(
        f"Recommended Order Quantity: "
        f"{optimization_result['recommended_order']} units"
    )

    print(
        f"Estimated Procurement Cost: "
        f"${optimization_result['total_cost']}"
    )

    print(
        f"\nDecision Status: "
        f"{critic_result['status']}"
    )

    # ======================================
    # Market Insights
    # ======================================

    print("\nTop Market Insights:\n")

    for i, insight in enumerate(market_insights, 1):

        print(f"{i}. {insight}")

    # ======================================
    # Risk Flags
    # ======================================

    print("\nRisk Flags:\n")

    if len(critic_result["issues"]) == 0:

        print("No major procurement risks detected.")

    else:

        for issue in critic_result["issues"]:

            print(f"- {issue}")

    # ======================================
    # Final Recommendation
    # ======================================

    print("\nFinal AI Recommendation:\n")

    if critic_result["status"] == "PASS":

        print(
            "Proceed with procurement plan."
        )

    else:

        print(
            "Revise procurement strategy "
            "before placing order."
        )

    print("\n======================================")

# %%
# ==========================================
# Full AI Procurement Pipeline
# ==========================================

sku = "ITEM_001"

predicted_demand = 420

# Phase 4 Optimization
result = optimize_inventory(
    predicted_demand=predicted_demand
)

# Phase 5 Critic
review = critic_refiner(
    predicted_demand=predicted_demand,
    optimization_result=result,
    market_query="Which suppliers are risky?"
)

# Phase 6 Report
generate_procurement_report(
    sku=sku,
    predicted_demand=predicted_demand,
    optimization_result=result,
    critic_result=review,
    market_query="Which suppliers are risky?"
)
# Out:
# ======================================
#  PROCUREMENT EXECUTIVE REPORT
# ======================================
#
# SKU: ITEM_001
#
# Predicted 4-Week Demand: 420 units
# Recommended Order Quantity: 420 units
# Estimated Procurement Cost: $21840.0
#
# Decision Status: REVISE
#
# Top Market Insights:
#
# 1. Supplier B offers 8% volume discount above 500 units.
# 2. Supplier C has been blacklisted in winter months due to delays.
# 3. Sea freight rates from Shanghai up 30% use air for urgent orders.
#
# Risk Flags:
#
# - Risk detected: Supplier issues found.
# - Logistics warning: Freight costs rising.
#
# Final AI Recommendation:
#
# Revise procurement strategy before placing order.
#
# ======================================
